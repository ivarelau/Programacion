# %% [markdown]
# # NOTEBOOK 03 - PARTE I Ejecución Condicional, Bucles, Listas y su Procesamiento
#
# ## Fundamentos de Python | UMCA
#
# ## Profesor: Ing. Andrés Mena Abarca
#
# ### <mark>**Nombre del estudiante:Ismael**</mark>
#
# * * *
#
# ## **1\. Valores Booleanos**
#
# ### 1.1. **Teoría**
#
# En Python, los valores booleanos son un tipo de dato que solo pueden tener dos valores: `True` (verdadero) y `False` (falso). Estos valores son fundamentales para el control de flujo en los programas, permitiendo que se tomen decisiones basadas en condiciones.
#
# - `True` y `False` son palabras clave en Python.
# - Se usan principalmente en expresiones condicionales y bucles.
#
# #### **Operadores de comparación**: Estos operadores devuelven un valor booleano como resultado de comparar dos valores.
#
# - `==` (igual a)
# - `!=` (diferente de)
# - `<`, `>`, `<=`, `>=` (menor, mayor, menor o igual, mayor o igual)
#
# ### 1.2. **Ejemplo de Código**

# %%
# Ejemplo de valores booleanos
x = 10
y = 20

# Operación de comparación
es_mayor = x > y  # False porque 10 no es mayor que 20
es_igual = x == y  # False porque 10 no es igual a 20

print(f"¿Es {x} mayor que {y}? {es_mayor}")
print(f"¿Es {x} igual a {y}? {es_igual}")

# %% [markdown]
# ### <mark>1.3. **Ejercicio Práctico**</mark>
#
# **Caso de Aplicación: Evaluación de Edades para una Competencia Deportiva**
#
# Imagina que estás organizando una competencia deportiva y necesitas verificar si un participante es elegible para competir en una categoría específica de edad. En esta categoría, los participantes deben tener entre **18 y 30 años** (inclusive). También se deben evaluar dos edades de los participantes, para ver quién es mayor o si tienen la misma edad.
#
# El ejercicio requerirá:
#
# - Evaluar si un participante es elegible para competir según su edad.
# - Comparar las edades de dos participantes para determinar quién es mayor.
#
# **Proceso**
#
# 1. **Solicita** <span style="color: var(--vscode-foreground);"> al usuario que ingrese la edad de dos participantes (edad1 y edad2).</span>
# 2. **Verifica** <span style="color: var(--vscode-foreground);"> si cada uno de ellos es elegible para la competencia (la edad debe estar entre 18 y 30 años inclusive).</span>
#
# 3. **Compara** las edades de los dos participantes:
#         - ¿Quién es mayor?
#         - ¿Son de la misma edad?
# 4. **Imprime** resultados detallados de las evaluaciones.

# %%
#Respuesta
#ENTRADA
edad1 = int(input("Ingrese la edad de primer participante: "))
edad2 = int(input("Ingrese la edad del segundo participante: "))

#Procesos
if (edad1 < 30 and edad1 > 18):
  print("El participante puede ingresar a la carrera!")
else:
  print("La edad del participate 1 no cumple con los requisitos")
  
  #Participante 2
  if (edad2 < 30 and edad2 > 18):
  print("El participante puede ingresar a la carrera!")
else:
  print("La edad del participate 2 no cumple con los requisitos")

if (edad1 == edad2):
  print("los participantes tine la misma edad")
else:
  print("las edades de los 2 participantes no es igual")

if (edad1 < edad2):
  print("La edad del participante 1 es menor a el participante 2")
else:
  print("las edades de los 2 participantes no es igual")

# %% [markdown]
# ## **2\. Ejecución Condicional**
#
# ### 2.1. **Teoría**
#
# La ejecución condicional permite que el programa tome decisiones y ejecute diferentes bloques de código basados en ciertas condiciones. En Python, las estructuras condicionales más comunes son `if`, `elif` (else if) y `else`.
#
# ### **Estructura básica:**
#
# ```Python
# if condición:
#     # Código si la condición es True
# elif otra_condición:
#     # Código si otra_condición es True
# else:
#     # Código si ninguna condición es True
#
# ```
#
# ### 2.2. **Ejemplo de Código: Clasificación de Calificaciones**
#
# #### **Contexto:**
#
# Imagina que estás desarrollando un sistema para clasificar las calificaciones de un grupo de estudiantes. El sistema debe recibir una calificación y asignar una letra basada en la siguiente escala:
#
# - Si la calificación es mayor o igual a 90, el estudiante obtiene una **A**.
# - Si la calificación está entre 80 y 89, el estudiante obtiene una **B**.
# - Si la calificación está entre 70 y 79, el estudiante obtiene una **C**.
# - Si la calificación está entre 60 y 69, el estudiante obtiene una **D**.
# - Si la calificación es menor que 60, el estudiante obtiene una **F**.
#
# ### **Estructura Condicional**
#
# Usaremos una serie de sentencias `if`, `elif` y `else` para implementar esta lógica.

# %%
#Respuesta
# Ejemplo mejorado: Clasificación de calificaciones de un estudiante
#Notas
notas = int(input("Ingrese la nota:"))
if (notas >= 90):
  print("Su nota es de A")
else:
  print("Su nota es menor a A")

if (notas >= 80):
  print("Su nota es de B")
else:
  print("Su nota es menor a B")

if (notas >= 70):
  print("Su nota es de C")
else:
  print("Su nota es menor a C")

if (notas >= 60):
  print("Su nota es de D")
else:
  print("Su nota es menor a D")

if (notas <= 60):
  print("Su nota es de F")
else:
  print("Su nota es menor a F")
# Out:
# Su nota es de A
# Su nota es de B
# Su nota es de C
# Su nota es de D
# Su nota es menor a F

# %% [markdown]
# ### <mark>2.3. **Ejercicio Práctico**</mark>
#
# ### Escribe un programa que pida al usuario ingresar su edad. Luego, el programa debe imprimir si es mayor o menor de edad (asumiendo 18 años como el límite).
#
# - El programa pide al usuario ingresar su edad.
# - Si el usuario ingresa un valor no válido (por ejemplo, texto o números negativos), le solicita nuevamente que ingrese un número válido.
# - Dependiendo de la edad ingresada, el programa:
#     - Imprime si es "menor de edad" (menor de 18).
#     - Imprime si es "mayor de edad" (18 años o más).
#     - Opcionalmente, imprime un mensaje especial para niños menores de 13 años o personas mayores de 65 años.
# - Permite que el usuario repita el proceso tantas veces como desee. \*\*\*OPCIONAL

# %%
# Declaración de variables
# Ejercicio para verificar si una persona es mayor o menor de edad
while True:
    try:
        edad = int(input("Ingrese la edad"))

        if not(edad > 0 and edad < 130):
            print("Edad ingrese no válida, ingrese nueva mente la edad")
            continue

        if edad > 18:
            print("Es mayor de edad")

        if edad < 18:
            print("Es menor de edad")

        if edad <= 13:
            print("Usted es un niño")

        if edad <= 65:
            print("Ustes es un adulto mayor")

        #prreguntar al ususario si quiere otra edad
        repetir = input('Quiere ngresar otra edad? (s/n):')
        if repetir != 's':
            print('Gracias por usar el programa, hasta luego')
            break #Termina el bucle o ciclo
        
    except ValueError:
        print("Error: Porfavor ingrese un valor númerico")
# Out:
# Error: Porfavor ingrese un valor númerico
# Es menor de edad
# Usted es un niño
# Ustes es un adulto mayor
# Gracias por usar el programa, hasta luego

# %% [markdown]
# ## **3\. Bucles**
#
# ### 3.1. **Teoría**
#
# Los bucles permiten repetir un bloque de código varias veces. Python tiene dos tipos principales de bucles: `for` y `while`.
#
# - **Bucle `for`:** Se utiliza para iterar sobre una secuencia (listas, tuplas, cadenas, etc.).
# - **Bucle `while`:** Repite un bloque de código mientras una condición sea `True`.
#
# ### 3.2. **Ejemplo de Código**
#
# ###
#
# - **Bucle `for`:**

# %%
# Ejemplo de bucle for
for i in range(1,10):
    print(f"Interación número {i}")
# Out:
# Interación número 1
# Interación número 2
# Interación número 3
# Interación número 4
# Interación número 5
# Interación número 6
# Interación número 7
# Interación número 8
# Interación número 9

# %% [markdown]
# ### **Caso: Suma de numeros del 1 a la cantidad que defina el usuario.**
#
# Vamos a suponer que queremos calcular la suma de los números del 1 a la catidad que deficna el suario. Este caso es útil para entender cómo funciona el bucle `for`, ya que iteramos sobre una secuencia de números y realizamos una operación en cada iteración.

# %%
#Respuesta
num = int(input("Ingrese el número hasta el que se va a relizar la suma: "))
suma = 0
for n in range(1, num + 1):
  suma = suma + n
  print(suma)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210
# 231
# 253
# 276
# 300
# 325
# 351
# 378
# 406
# 435
# 465
# 496
# 528
# 561
# 595
# 630
# 666
# 703
# 741
# 780
# 820
# 861
# 903
# 946
# 990
# 1035
# 1081
# 1128
# 1176
# 1225
# 1275
# 1326
# 1378
# 1431
# 1485
# 1540
# 1596
# 1653
# 1711
# 1770
# 1830
# 1891
# 1953
# 2016
# 2080
# 2145
# 2211
# 2278
# 2346
# 2415
# 2485
# 2556
# 2628
# 2701
# 2775
# 2850
# 2926
# 3003
# 3081
# 3160
# 3240
# 3321
# 3403
# 3486
# 3570
# 3655
# 3741
# 3828
# 3916
# 4005
# 4095
# 4186
# 4278
# 4371
# 4465
# 4560
# 4656
# 4753
# 4851
# 4950
# 5050
# 5151
# 5253
# 5356
# 5460
# 5565
# 5671
# 5778
# 5886
# 5995
# 6105
# 6216
# 6328
# 6441
# 6555
# 6670
# 6786
# 6903
# 7021
# 7140
# 7260
# 7381
# 7503
# 7626
# 7750
# 7875
# 8001
# 8128
# 8256
# 8385
# 8515
# 8646
# 8778
# 8911
# 9045
# 9180
# 9316
# 9453
# 9591
# 9730
# 9870
# 10011
# 10153
# 10296
# 10440
# 10585
# 10731
# 10878
# 11026
# 11175
# 11325
# 11476
# 11628
# 11781
# 11935
# 12090
# 12246
# 12403
# 12561
# 12720
# 12880
# 13041
# 13203
# 13366
# 13530
# 13695
# 13861
# 14028
# 14196
# 14365
# 14535
# 14706
# 14878
# 15051
# 15225
# 15400
# 15576
# 15753
# 15931
# 16110
# 16290
# 16471
# 16653
# 16836
# 17020
# 17205
# 17391
# 17578
# 17766
# 17955
# 18145
# 18336
# 18528
# 18721
# 18915
# 19110
# 19306
# 19503
# 19701
# 19900
# 20100
# 20301
# 20503
# 20706
# 20910
# 329266
# 330078
# 330891
# 331705
# 332520
# 333336
# 334153
# 334971
# 335790
# 336610
# 337431
# 338253
# 339076
# 339900
# 340725
# 341551
# 342378
# 343206
# 344035
# 344865
# 345696
# 346528
# 347361
# 348195
# 349030
# 349866
# 350703
# 351541
# 352380
# 353220
# 354061
# 354903
# 355746
# 356590
# 357435
# 358281
# 359128
# 359976
# 360825
# 361675
# 362526
# 363378
# 364231
# 365085
# 365940
# 366796
# 367653
# 368511
# 369370
# 370230
# 371091
# 371953
# 372816
# 373680
# 374545
# 375411
# 376278
# 377146
# 378015
# 378885
# 379756
# 380628
# 381501
# 382375
# 383250
# 384126
# 385003
# 385881
# 386760
# 387640
# 388521
# 389403
# 390286
# 391170
# 392055
# 392941
# 393828
# 394716
# 395605
# 396495
# 397386
# 398278
# 399171
# 400065
# 400960
# 401856
# 402753
# 403651
# 404550
# 405450
# 406351
# 407253
# 408156
# 409060
# 409965
# 410871
# 411778
# 412686
# 413595
# 414505
# 415416
# 416328
# 417241
# 418155
# 419070
# 419986
# 420903
# 421821
# 422740
# 423660
# 424581
# 425503
# 426426
# 427350
# 428275
# 429201
# 430128
# 431056
# 431985
# 432915
# 433846
# 434778
# 435711
# 436645
# 437580
# 438516
# 439453
# 440391
# 441330
# 442270
# 443211
# 444153
# 445096
# 446040
# 446985
# 447931
# 448878
# 449826
# 450775
# 451725
# 452676
# 453628
# 454581
# 455535
# 456490
# 457446
# 458403
# 459361
# 460320
# 461280
# 462241
# 463203
# 464166
# 465130
# 466095
# 467061
# 468028
# 468996
# 469965
# 470935
# 471906
# 472878
# 473851
# 474825
# 475800
# 476776
# 477753
# 478731
# 479710
# 480690
# 481671
# 482653
# 483636
# 484620
# 485605
# 486591
# 487578
# 488566
# 489555
# 490545
# 491536
# 492528
# 493521
# 494515
# 495510
# 496506
# 497503
# 498501
# 499500
# 500500

# %% [markdown]
# ###
#
# - **Bucle** `while`:

# %%
# Ejemplo de bucle while

producto = int(input("Ingrese un número hasta el que se va realizar la suma: "))
producto = 1
suma = 0
while contador < num + 1:
    suma += contador # suma = suma + contador
    print(f'Contador: {contador}')
    contador += 1
print("LA suma total es: ", suma)
# Out:
# Contador: 1
# Contador: 2
# Contador: 3
# Contador: 4
# Contador: 5
# Contador: 6
# Contador: 7
# Contador: 8
# Contador: 9
# Contador: 10
# Contador: 11
# Contador: 12
# Contador: 13
# Contador: 14
# Contador: 15
# Contador: 16
# Contador: 17
# Contador: 18
# Contador: 19
# Contador: 20
# Contador: 21
# Contador: 22
# Contador: 23
# Contador: 24
# Contador: 25
# Contador: 26
# Contador: 27
# Contador: 28
# Contador: 29
# Contador: 30
# Contador: 31
# Contador: 32
# Contador: 33
# Contador: 34
# Contador: 35
# Contador: 36
# Contador: 37
# Contador: 38
# Contador: 39
# Contador: 40
# Contador: 41
# Contador: 42
# Contador: 43
# Contador: 44
# Contador: 45
# Contador: 46
# Contador: 47
# Contador: 48
# Contador: 49
# Contador: 50
# Contador: 51
# Contador: 52
# Contador: 53
# Contador: 54
# Contador: 55
# Contador: 56
# Contador: 57
# Contador: 58
# Contador: 59
# Contador: 60
# Contador: 61
# Contador: 62
# Contador: 63
# Contador: 64
# Contador: 65
# Contador: 66
# Contador: 67
# Contador: 68
# Contador: 69
# Contador: 70
# Contador: 71
# Contador: 72
# Contador: 73
# Contador: 74
# Contador: 75
# Contador: 76
# Contador: 77
# Contador: 78
# Contador: 79
# Contador: 80
# Contador: 81
# Contador: 82
# Contador: 83
# Contador: 84
# Contador: 85
# Contador: 86
# Contador: 87
# Contador: 88
# Contador: 89
# Contador: 90
# Contador: 91
# Contador: 92
# Contador: 93
# Contador: 94
# Contador: 95
# Contador: 96
# Contador: 97
# Contador: 98
# Contador: 99
# Contador: 100
# Contador: 101
# Contador: 102
# Contador: 103
# Contador: 104
# Contador: 105
# Contador: 106
# Contador: 107
# Contador: 108
# Contador: 109
# Contador: 110
# Contador: 111
# Contador: 112
# Contador: 113
# Contador: 114
# Contador: 115
# Contador: 116
# Contador: 117
# Contador: 118
# Contador: 119
# Contador: 120
# Contador: 121
# Contador: 122
# Contador: 123
# Contador: 124
# Contador: 125
# Contador: 126
# Contador: 127
# Contador: 128
# Contador: 129
# Contador: 130
# Contador: 131
# Contador: 132
# Contador: 133
# Contador: 134
# Contador: 135
# Contador: 136
# Contador: 137
# Contador: 138
# Contador: 139
# Contador: 140
# Contador: 141
# Contador: 142
# Contador: 143
# Contador: 144
# Contador: 145
# Contador: 146
# Contador: 147
# Contador: 148
# Contador: 149
# Contador: 150
# Contador: 151
# Contador: 152
# Contador: 153
# Contador: 154
# Contador: 155
# Contador: 156
# Contador: 157
# Contador: 158
# Contador: 159
# Contador: 160
# Contador: 161
# Contador: 162
# Contador: 163
# Contador: 164
# Contador: 165
# Contador: 166
# Contador: 167
# Contador: 168
# Contador: 169
# Contador: 170
# Contador: 171
# Contador: 172
# Contador: 173
# Contador: 174
# Contador: 175
# Contador: 176
# Contador: 177
# Contador: 178
# Contador: 179
# Contador: 180
# Contador: 181
# Contador: 182
# Contador: 183
# Contador: 184
# Contador: 185
# Contador: 186
# Contador: 187
# Contador: 188
# Contador: 189
# Contador: 190
# Contador: 191
# Contador: 192
# Contador: 193
# Contador: 194
# Contador: 195
# Contador: 196
# Contador: 197
# Contador: 198
# Contador: 199
# Contador: 200
# Contador: 201
# Contador: 202
# Contador: 203
# Contador: 204
# Contador: 205
# Contador: 206
# Contador: 207
# Contador: 208
# Contador: 209
# Contador: 210
# Contador: 211
# Contador: 212
# Contador: 213
# Contador: 214
# Contador: 215
# Contador: 216
# Contador: 217
# Contador: 218
# Contador: 219
# Contador: 220
# Contador: 221
# Contador: 222
# Contador: 223
# Contador: 224
# Contador: 225
# Contador: 226
# Contador: 227
# Contador: 228
# Contador: 229
# Contador: 230
# Contador: 231
# Contador: 232
# Contador: 233
# Contador: 234
# Contador: 235
# Contador: 236
# Contador: 237
# Contador: 238
# Contador: 239
# Contador: 240
# Contador: 430
# Contador: 431
# Contador: 432
# Contador: 433
# Contador: 434
# Contador: 435
# Contador: 436
# Contador: 437
# Contador: 438
# Contador: 439
# Contador: 440
# Contador: 441
# Contador: 442
# Contador: 443
# Contador: 444
# Contador: 445
# Contador: 446
# Contador: 447
# Contador: 448
# Contador: 449
# Contador: 450
# Contador: 451
# Contador: 452
# Contador: 453
# Contador: 454
# Contador: 455
# Contador: 456
# Contador: 457
# Contador: 458
# Contador: 459
# Contador: 460
# Contador: 461
# Contador: 462
# Contador: 463
# Contador: 464
# Contador: 465
# Contador: 466
# Contador: 467
# Contador: 468
# Contador: 469
# Contador: 470
# Contador: 471
# Contador: 472
# Contador: 473
# Contador: 474
# Contador: 475
# Contador: 476
# Contador: 477
# Contador: 478
# Contador: 479
# Contador: 480
# Contador: 481
# Contador: 482
# Contador: 483
# Contador: 484
# Contador: 485
# Contador: 486
# Contador: 487
# Contador: 488
# Contador: 489
# Contador: 490
# Contador: 491
# Contador: 492
# Contador: 493
# Contador: 494
# Contador: 495
# Contador: 496
# Contador: 497
# Contador: 498
# Contador: 499
# Contador: 500
# Contador: 501
# Contador: 502
# Contador: 503
# Contador: 504
# Contador: 505
# Contador: 506
# Contador: 507
# Contador: 508
# Contador: 509
# Contador: 510
# Contador: 511
# Contador: 512
# Contador: 513
# Contador: 514
# Contador: 515
# Contador: 516
# Contador: 517
# Contador: 518
# Contador: 519
# Contador: 520
# Contador: 521
# Contador: 522
# Contador: 523
# Contador: 524
# Contador: 525
# Contador: 526
# Contador: 527
# Contador: 528
# Contador: 529
# Contador: 530
# Contador: 531
# Contador: 532
# Contador: 533
# Contador: 534
# Contador: 535
# Contador: 536
# Contador: 537
# Contador: 538
# Contador: 539
# Contador: 540
# Contador: 541
# Contador: 542
# Contador: 543
# Contador: 544
# Contador: 545
# Contador: 546
# Contador: 547
# Contador: 548
# Contador: 549
# Contador: 550
# Contador: 551
# Contador: 552
# Contador: 553
# Contador: 554
# Contador: 555
# Contador: 556
# Contador: 557
# Contador: 558
# Contador: 559
# Contador: 560
# Contador: 561
# Contador: 562
# Contador: 563
# Contador: 564
# Contador: 565
# Contador: 566
# Contador: 567
# Contador: 568
# Contador: 569
# Contador: 570
# Contador: 571
# Contador: 572
# Contador: 573
# Contador: 574
# Contador: 575
# Contador: 576
# Contador: 577
# Contador: 578
# Contador: 579
# Contador: 580
# Contador: 581
# Contador: 582
# Contador: 583
# Contador: 584
# Contador: 585
# Contador: 586
# Contador: 587
# Contador: 588
# Contador: 589
# Contador: 590
# Contador: 591
# Contador: 592
# Contador: 593
# Contador: 594
# Contador: 595
# Contador: 596
# Contador: 597
# Contador: 598
# Contador: 599
# Contador: 600
# Contador: 601
# Contador: 602
# Contador: 603
# Contador: 604
# Contador: 605
# Contador: 606
# Contador: 607
# Contador: 608
# Contador: 609
# Contador: 610
# Contador: 611
# Contador: 612
# Contador: 613
# Contador: 614
# Contador: 615
# Contador: 616
# Contador: 617
# Contador: 618
# Contador: 619
# Contador: 620
# Contador: 621
# Contador: 622
# Contador: 623
# Contador: 624
# Contador: 625
# Contador: 626
# Contador: 627
# Contador: 628
# Contador: 629
# Contador: 630
# Contador: 631
# Contador: 632
# Contador: 633
# Contador: 634
# Contador: 635
# Contador: 636
# Contador: 637
# Contador: 638
# Contador: 639
# Contador: 640
# Contador: 641
# Contador: 642
# Contador: 643
# Contador: 644
# Contador: 645
# Contador: 646
# Contador: 647
# Contador: 648
# Contador: 649
# Contador: 650
# Contador: 651
# Contador: 652
# Contador: 653
# Contador: 654
# Contador: 655
# Contador: 656
# Contador: 657
# Contador: 658
# Contador: 659
# Contador: 660
# Contador: 661
# Contador: 662
# Contador: 663
# Contador: 664
# Contador: 665
# Contador: 666
# Contador: 667
# Contador: 668
# Contador: 669
# Contador: 670
# Contador: 671
# Contador: 672
# Contador: 673
# Contador: 674
# Contador: 675
# Contador: 676
# Contador: 677
# Contador: 678
# Contador: 679
# Contador: 680
# Contador: 681
# Contador: 682
# Contador: 683
# Contador: 684
# Contador: 685
# Contador: 686
# Contador: 687
# Contador: 688
# Contador: 689
# Contador: 690
# Contador: 691
# Contador: 692
# Contador: 693
# Contador: 694
# Contador: 695
# Contador: 696
# Contador: 697
# Contador: 698
# Contador: 699
# Contador: 700
# Contador: 701
# Contador: 702
# Contador: 703
# Contador: 704
# Contador: 705
# Contador: 706
# Contador: 707
# Contador: 708
# Contador: 709
# Contador: 710
# Contador: 711
# Contador: 712
# Contador: 713
# Contador: 714
# Contador: 715
# Contador: 716
# Contador: 717
# Contador: 718
# Contador: 719
# Contador: 720
# Contador: 721
# Contador: 722
# Contador: 723
# Contador: 724
# Contador: 725
# Contador: 726
# Contador: 727
# Contador: 728
# Contador: 729
# Contador: 730
# Contador: 731
# Contador: 732
# Contador: 733
# Contador: 734
# Contador: 735
# Contador: 736
# Contador: 737
# Contador: 738
# Contador: 739
# Contador: 740
# Contador: 741
# Contador: 742
# Contador: 743
# Contador: 744
# Contador: 745
# Contador: 746
# Contador: 747
# Contador: 748
# Contador: 749
# Contador: 750
# Contador: 751
# Contador: 752
# Contador: 753
# Contador: 754
# Contador: 755
# Contador: 756
# Contador: 757
# Contador: 758
# Contador: 759
# Contador: 760
# Contador: 761
# Contador: 762
# Contador: 763
# Contador: 764
# Contador: 765
# Contador: 766
# Contador: 767
# Contador: 768
# Contador: 769
# Contador: 770
# Contador: 771
# Contador: 772
# Contador: 773
# Contador: 774
# Contador: 775
# Contador: 776
# Contador: 777
# Contador: 778
# Contador: 779
# Contador: 780
# Contador: 781
# Contador: 782
# Contador: 783
# Contador: 784
# Contador: 785
# Contador: 786
# Contador: 787
# Contador: 788
# Contador: 789
# Contador: 790
# Contador: 791
# Contador: 792
# Contador: 793
# Contador: 794
# Contador: 795
# Contador: 796
# Contador: 797
# Contador: 798
# Contador: 799
# Contador: 800
# Contador: 801
# Contador: 802
# Contador: 803
# Contador: 804
# Contador: 805
# Contador: 806
# Contador: 807
# Contador: 808
# Contador: 809
# Contador: 810
# Contador: 811
# Contador: 812
# Contador: 813
# Contador: 814
# Contador: 815
# Contador: 816
# Contador: 817
# Contador: 818
# Contador: 819
# Contador: 820
# Contador: 821
# Contador: 822
# Contador: 823
# Contador: 824
# Contador: 825
# Contador: 826
# Contador: 827
# Contador: 828
# Contador: 829
# Contador: 830
# Contador: 831
# Contador: 832
# Contador: 833
# Contador: 834
# Contador: 835
# Contador: 836
# Contador: 837
# Contador: 838
# Contador: 839
# Contador: 840
# Contador: 841
# Contador: 842
# Contador: 843
# Contador: 844
# Contador: 845
# Contador: 846
# Contador: 847
# Contador: 848
# Contador: 849
# Contador: 850
# Contador: 851
# Contador: 852
# Contador: 853
# Contador: 854
# Contador: 855
# Contador: 856
# Contador: 857
# Contador: 858
# Contador: 859
# Contador: 860
# Contador: 861
# Contador: 862
# Contador: 863
# Contador: 864
# Contador: 865
# Contador: 866
# Contador: 867
# Contador: 868
# Contador: 869
# Contador: 870
# Contador: 871
# Contador: 872
# Contador: 873
# Contador: 874
# Contador: 875
# Contador: 876
# Contador: 877
# Contador: 878
# Contador: 879
# Contador: 880
# Contador: 881
# Contador: 882
# Contador: 883
# Contador: 884
# Contador: 885
# Contador: 886
# Contador: 887
# Contador: 888
# Contador: 889
# Contador: 890
# Contador: 891
# Contador: 892
# Contador: 893
# Contador: 894
# Contador: 895
# Contador: 896
# Contador: 897
# Contador: 898
# Contador: 899
# Contador: 900
# Contador: 901
# Contador: 902
# Contador: 903
# Contador: 904
# Contador: 905
# Contador: 906
# Contador: 907
# Contador: 908
# Contador: 909
# Contador: 910
# Contador: 911
# Contador: 912
# Contador: 913
# Contador: 914
# Contador: 915
# Contador: 916
# Contador: 917
# Contador: 918
# Contador: 919
# Contador: 920
# Contador: 921
# Contador: 922
# Contador: 923
# Contador: 924
# Contador: 925
# Contador: 926
# Contador: 927
# Contador: 928
# Contador: 929
# Contador: 930
# Contador: 931
# Contador: 932
# Contador: 933
# Contador: 934
# Contador: 935
# Contador: 936
# Contador: 937
# Contador: 938
# Contador: 939
# Contador: 940
# Contador: 941
# Contador: 942
# Contador: 943
# Contador: 944
# Contador: 945
# Contador: 946
# Contador: 947
# Contador: 948
# Contador: 949
# Contador: 950
# Contador: 951
# Contador: 952
# Contador: 953
# Contador: 954
# Contador: 955
# Contador: 956
# Contador: 957
# Contador: 958
# Contador: 959
# Contador: 960
# Contador: 961
# Contador: 962
# Contador: 963
# Contador: 964
# Contador: 965
# Contador: 966
# Contador: 967
# Contador: 968
# Contador: 969
# Contador: 970
# Contador: 971
# Contador: 972
# Contador: 973
# Contador: 974
# Contador: 975
# Contador: 976
# Contador: 977
# Contador: 978
# Contador: 979
# Contador: 980
# Contador: 981
# Contador: 982
# Contador: 983
# Contador: 984
# Contador: 985
# Contador: 986
# Contador: 987
# Contador: 988
# Contador: 989
# Contador: 990
# Contador: 991
# Contador: 992
# Contador: 993
# Contador: 994
# Contador: 995
# Contador: 996
# Contador: 997
# Contador: 998
# Contador: 999
# Contador: 1000
# Contador: 1001
# Contador: 1002
# Contador: 1003
# Contador: 1004
# Contador: 1005
# Contador: 1006
# Contador: 1007
# Contador: 1008
# Contador: 1009
# Contador: 1010
# Contador: 1011
# Contador: 1012
# Contador: 1013
# Contador: 1014
# Contador: 1015
# Contador: 1016
# Contador: 1017
# Contador: 1018
# Contador: 1019
# Contador: 1020
# Contador: 1021
# Contador: 1022
# Contador: 1023
# Contador: 1024
# Contador: 1025
# Contador: 1026
# Contador: 1027
# Contador: 1028
# Contador: 1029
# Contador: 1030
# Contador: 1031
# Contador: 1032
# Contador: 1033
# Contador: 1034
# Contador: 1035
# Contador: 1036
# Contador: 1037
# Contador: 1038
# Contador: 1039
# Contador: 1040
# Contador: 1041
# Contador: 1042
# Contador: 1043
# Contador: 1044
# Contador: 1045
# Contador: 1046
# Contador: 1047
# Contador: 1048
# Contador: 1049
# Contador: 1050
# Contador: 1051
# Contador: 1052
# Contador: 1053
# Contador: 1054
# Contador: 1055
# LA suma total es:  557040

# %% [markdown]
# ### **Caso: Cálculo de Total de Compras**
#
# #### <span style="color: var(--vscode-foreground); font-weight: normal;">Imagina que estás desarrollando un pequeño programa para una tienda. Los clientes ingresan el precio de varios productos que están comprando, uno por uno. El programa debe seguir pidiendo el precio de cada producto hasta que el usuario indique que no va a ingresar más productos, y al final, debe calcular y mostrar el total a pagar.</span>

# %%
#Respuesta
while True:
    try:
        producto = int(input("Ingrese el precio del producto"))

        if not(producto > 0 and producto < 9999999999):
            print("La cantidad del precio no válida")
            continue


        
        repetir = input('Quiere ngresar otra edad? (s/n):')
        if repetir != 's':
            print('Gracias por venir a nuestra tienda, hasta luego')
            break 
        
    except ValueError:
        print("Error: Porfavor ingrese un valor númerico")
# Out:
# Gracias por venir a nuestra tienda, hasta luego

# %% [markdown]
# ### <mark>3.3. **Ejercicio Práctico -** Tabla de Multiplicar</mark>
#
# **Descripción:** Crea un programa que pida al usuario un número entero `n` y muestre la tabla de multiplicar de ese número del 1 al 10. Utiliza un ciclo `while` para generar la tabla.
#
# **Instrucciones:**
#
# 1. Solicita al usuario que ingrese un número entero.
# 2. Inicializa una variable `i` en 1.
# 3. Utiliza un ciclo `while` para que mientras `i` sea menor o igual a 10:
#     - Multiplica `n` por `i` y muestra el resultado en el formato "n x i = resultado".
#     - Incrementa `i` en 1.
# 4. Al final, muestra la tabla completa.
#
# **Ejemplo de salida:**
#
# ```
#
# Ingrese un número entero: 3
# Tabla de multiplicar de 3:
#
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
#
# ```

# %%
#Respuesta

# %% [markdown]
# #### <mark>3.3. Ejercicio Práctico</mark>
#
# Escribe un programa que imprima los números del 1 al 10 usando un bucle for. Luego, realiza el mismo ejercicio con un bucle while.

# %%
#Respuesta

# %% [markdown]
# **Caso 2: Suma de Números**
# - **Presentación:** Supongamos que tienes una lista de números y quieres calcular la suma total. ¿Cómo podrías hacer esto en Python?
# - **Salida Esperada:**
#     - La suma total de los números en la lista.
# - **Preguntas adicionales:**
#     - ¿Cómo podrías calcular el promedio de los números?
#     - ¿Y si quisieras encontrar el número más grande y el más pequeño?
#     - ¿Puedes modificar el código para que solo sume los números pares?

# %% [markdown]
# ## **4\. Listas y su Procesamiento**
#
# ### 4.1. **Teoría**
#
# Una lista es una estructura de datos en Python que almacena múltiples elementos en un solo objeto. Las listas son mutables, lo que significa que podemos modificar su contenido después de haberlas creado.
#
# ### **Operaciones comunes con listas:**
#
# - **Añadir elementos:** `append()`, `insert()`
# - **Eliminar elementos:** `remove()`, `pop()`
# - **Acceso a elementos:** Índices
# - **Slicing:** Obtener sublistas
#
# ### 4.2. **Ejemplo de Código**

# %%
# Ejemplo de procesamiento de listas

# %% [markdown]
# ### <mark>4.3. **Ejercicio Práctico**</mark>
#
# Imagina que quieres crear una lista de tus amigos. ¿Cómo podrías almacenar estos nombres en Python? Una vez que tengas la lista, ¿cómo podrías agregar un nuevo amigo? ¿Y cómo podrías saludar a cada uno de ellos?
#
# ```
# amigos = ["Ana", "Juan", "María", "Pedro"\] \# ... (resto del código)
#
# ```
#
# **Salida Esperada:**
#
# ```
# - Una lista impresa con todos los nombres de los amigos.
# - El nombre del tercer amigo.
# - Un saludo personalizado para cada amigo.
#
# ```
#
# **Preguntas adicionales:**
#
# ```
# - ¿Cómo podrías eliminar a un amigo de la lista?
# - ¿Qué pasa si quieres cambiar el nombre de un amigo?
# - ¿Puedes ordenar la lista alfabéticamente?
#
# ```

# %%
#Respuesta

# %% [markdown]
# ## **4\. Listas y su Procesamiento**
#
# ### 4.1. **Teoría**
#
# Una lista es una estructura de datos en Python que almacena múltiples elementos en un solo objeto. Las listas son mutables, lo que significa que podemos modificar su contenido después de haberlas creado.
#
# ### **Operaciones comunes con listas:**
#
# - **Añadir elementos:** `append()`, `insert()`
# - **Eliminar elementos:** `remove()`, `pop()`
# - **Acceso a elementos:** Índices
# - **Slicing:** Obtener sublistas
#
# ### 4.2. **Ejemplo de Código**

# %%
# Ejemplo de procesamiento de listas
#             0          1          2

# %% [markdown]
# **append(elemento):**
#
# - Agrega un elemento al final de la lista.

# %% [markdown]
# **insert(índice, elemento):**
#
# - Inserta un elemento en una posición específica de la lista.
# - El índice indica la posición antes de la cual se insertará el elemento.

# %% [markdown]
# **remove(elemento):**
#
# - Elimina la primera ocurrencia de un elemento específico de la lista.
# - Si el elemento no existe, se produce un error.

# %% [markdown]
# **pop(índice):**
#
# - Elimina y devuelve el elemento en la posición indicada.
# - Si no se especifica un índice, elimina y devuelve el último elemento.

# %% [markdown]
# ### **<mark>Caso Final</mark>**
#
#
#
# Un profesor quiere llevar un registro de los nombres de sus estudiantes. Ayúdale a crear un programa que le permita agregar nuevos estudiantes, ver la lista completa y acceder a la información de un estudiante en particular.
